# %% [markdown]
# $ \newcommand{\norm}[1]{\left\Vert#1\right\Vert} $
# $ \newcommand{\abs}[1]{\left\vert#1\right\vert} $
# $ \newcommand{\Rar}{\Longrightarrow} $
# $ \newcommand{\Dar}{\Longleftrightarrow} $
#
# # Métodos de Taylor
#
# ## $ \S 1 $ Introdução
#
# Seja $ \boldsymbol y $ a solução de um problema de valor inicial de primeira ordem em $ \mathbb R^r $:
# \begin{equation*}\label{E:ivp}
# \begin{cases}
# \boldsymbol y' = \boldsymbol F(t, \boldsymbol y) \\
# \boldsymbol y(t_0) = \boldsymbol y_0
# \end{cases}
# \quad \text{onde} \quad \boldsymbol y = \big(y_0, y_1, \dots, y_{r-1}\big)\,. \tag{1}
# \end{equation*}
#
# Usando o polinômio de Taylor de ordem $ m \ge 1 $ de $ \boldsymbol y $ ao redor de
# $ t $, obtemos uma aproximação para $ \boldsymbol y(t+h) $ a partir da informação dos
# valores de $ \boldsymbol y $ e suas derivadas de ordens até $ m $ em $ t $:
# \begin{equation*}\label{E:Taylor}
# \boldsymbol y(t+h) \approx \boldsymbol y(t) + h\,\boldsymbol y'(t) + \frac{h^2}{2}\,\boldsymbol y''(t) + \cdots + \frac{h^m}{m!}\boldsymbol y^{(m)}(t)\,. \tag{2}
# \end{equation*}
# Pela fórmula para o resto no teorema de Taylor, o erro envolvido é aproximadamente proporcional a $ \abs{h}^{m+1} $. Portanto, para $ \abs{h} $ próximo de $ 0 $, quanto maior o valor de $ m $, melhor é esta aproximação.
#
# A estimativa dada por \eqref{E:Taylor} é a base do *método de Taylor de ordem* $ m $, do qual o método de Euler é o caso especial em que $ m = 1 $. Antes de detalhá-lo, precisamos expressar as sucessivas derivadas de $ \boldsymbol y $ em $ t $ usando apenas $ t $ e o valor de $ \boldsymbol y $ em $ t $.
#
# ## $ \S 2 $ O método de Taylor de ordem $ m $
#
# ### $ 2.1 $ Expressando $ \boldsymbol y^{(j)}(t) $ em termos de $ t $ e $ \boldsymbol y(t) $
#
# Se $ \boldsymbol y $ é a solução analítica do problema de valor inicial \eqref{E:ivp}, então
# \begin{equation*}\label{E:derivative}
# \boldsymbol y'(t) = \boldsymbol F\big(t, \boldsymbol y(t)\big)\,. \tag{3}
# \end{equation*}
# Assim, podemos determinar $ \boldsymbol y'(t) $ usando o valor de $ \boldsymbol y(t) $.
#
# Derivando \eqref{E:derivative} com respeito a $ t $ usando a regra da cadeia, obtemos a seguinte fórmula para $ \boldsymbol y'' $:
# \begin{alignat*}{9}
# \boldsymbol y''(t) &= \frac{d}{dt} \boldsymbol F\big(t,\boldsymbol y(t)\big) \\
# &=\Bigg(\frac{\partial \boldsymbol F}{\partial t} \frac{dt}{dt} + \sum_{k=0}^{r-1} \frac{\partial \boldsymbol F}{\partial y_k} \frac{dy_k}{dt} \Bigg)\big(t,\boldsymbol y(t)\big) \\
# &= \Bigg(\boldsymbol F_t + \sum_{k=0}^{r-1}\boldsymbol F_{y_k} f_k\Bigg)\big(t,\boldsymbol y(t)\big) \,.\label{E:T2} \tag{4}
# \end{alignat*}
# Aqui
# $$
# \boldsymbol F = (f_0,f_1,\dots,f_{r-1})\,
# $$
# e no último passo usamos \eqref{E:derivative} para substituir a $ k $-ésima coordenada $ y_k' $ do lado esquerdo desta equação pela $ k $-ésima coordenada $ f_k $ do lado direito. Observe que a expressão \eqref{E:T2} não envolve $ \boldsymbol y' $, apenas $ \boldsymbol y $.
#
# Da mesma maneira, derivando sucessivamente \eqref{E:derivative} com respeito a $ t $, obtemos uma fórmula para $ \boldsymbol y^{(j)} $ da forma:
# \begin{equation*}\label{E:T}
# \boldsymbol y^{(j)}(t) = \boldsymbol T_j\big(t,\boldsymbol y(t)\big) \qquad (j = 1, 2, \dots)\,. \tag{5}
# \end{equation*}
# A expressão à direita é complicada, pois envolve todas as derivadas parciais de $ \boldsymbol F $ de ordem $ \le j - 1 $. Mas o ponto principal é que, por indução, podemos escrevê-la de modo que ela não envolva
# $$
# \boldsymbol y'(t),\ \boldsymbol y''(t), \cdots,\ \boldsymbol y^{(j-1)}(t)\,,
# $$
# apenas $ t $ e $ \boldsymbol y(t) $, como já indicado pela notação.
#
# ### $ 2.2 $ Descrição do método de Taylor de ordem $ m $
#
# Sejam $ N \ge 1 $ um inteiro, $ h \ne 0 $ o **tamanho do passo** e
# $$
# t_i = t_0 + ih \qquad (i = 0, 1, \dots, N)
# $$
# os **nodos** correspondentes.
#
# No **método de Taylor de ordem $ m $**, definimos a aproximação $ \boldsymbol y_i $ para o valor preciso $ \boldsymbol y(t_i) $ da solução analítica de \eqref{E:ivp} usando a estimativa $ \boldsymbol y_{i-1} $ no nodo anterior e a aproximação polinomial de ordem $ m $ em \eqref{E:Taylor}, mas substituindo $ \boldsymbol y^{(j)} $ pelo lado direito em \eqref{E:T} para cada $ j $:
# \begin{equation*}\label{E:m}
# \boxed{\boldsymbol y_{i} = \boldsymbol y_{i-1} + h\,\boldsymbol T_1\big(t_{i-1},\boldsymbol y_{i-1}\big) +
# \frac{h^2}{2}\,\boldsymbol T_2\big(t_{i-1},\boldsymbol y_{i-1}\big) + \cdots + \frac{h^m}{m!}\boldsymbol T_m\big(t_{i-1},\boldsymbol y_{i-1}\big)}\tag{6}
# \end{equation*}
# onde $t_i = t_0 + ih$ para cada $ i = 1, \dots, N $.
#
# 📝 Tomando $ m = 1 $, recuperamos o método de Euler.
#
# 📝 A fórmula geral acima ainda não é útil porque os $ \boldsymbol T_j $ não foram determinados. Faremos isto nas seções seguintes em casos especiais.
#
# ## $ \S 3 $ Fórmula do método de Taylor de ordem $ 2 $ para um problema de valor inicial vetorial
#
# Usando a notação da $ \S 2 $, concluímos de \eqref{E:derivative} e \eqref{E:T2} que
# $$
# \boxed{\boldsymbol T_1 = \boldsymbol F \quad \text{e} \quad \boldsymbol T_2 = \boldsymbol F_t + \sum_{k=0}^{r-1}\boldsymbol F_{y_k} f_k}
# $$
#
# Substituindo estas expressões em \eqref{E:m}, obtemos finalmente a fórmula para o **método de Taylor de ordem** $ 2 $:
# \begin{equation*}
# \boxed{\boldsymbol y_{i} = \boldsymbol y_{i-1} + h\,\boldsymbol F\big(t_{i-1},\boldsymbol y_{i-1}\big) +
# \frac{h^2}{2}\,\Bigg( \boldsymbol F_t + \sum_{k=0}^{r-1}\boldsymbol F_{y_k} f_k \Bigg)\big(t_{i-1},\boldsymbol y_{i-1}\big)}% \qquad \text{onde }\boldsymbol F = (f_0,f_1,\dots,f_{r-1})
# \end{equation*}
#
# ## $ \S 4 $ Fórmulas do método de Taylor de ordens $ 2 $  e $ 3 $ para um problema de valor inicial escalar
#
# Para simplificar a situação, considere um PVI de primeira ordem *escalar* (ou seja, com $ r = 1 $):
# \begin{equation*}
# \begin{cases}
# y' = f(t, y) \\
# y(t_0) = y_0
# \end{cases}
# \end{equation*}
# Como caso especial das fórmulas deduzidas na $ \S 3 $, sabemos que:
# $$
# \boxed{T_1 = f}
# $$
# e
# $$
# \boxed{\displaystyle{T_2 = f_t + f_y\,f}}
# $$
#
# Derivando $ T_2\big(t,y(t)\big) $ com respeito a $ t $ com ajuda da regra da cadeia (e omitindo os parâmetros por concisão), deduzimos que:
# \begin{alignat*}{9}
# T_3 &=\big(f_t + f_y\,f\big)_t + \big(f_t + f_y\,f\big)_y\,y' \\
# &=\big(f_t + f_y\,f\big)_t + \big(f_t + f_y\,f\big)_y\,f \\
# &= \boxed{f_{tt} + f_t\,f_y + 2f_{ty}\,f + f_{yy}\,f^2 +   f_y^2\,f}
# \end{alignat*}
#
# Substituindo as expressões para  $ T_1,\,T_2,\,T_3 $ em \eqref{E:m} obtemos as fórmulas dos métodos de Taylor de ordens $ 1 $, $ 2 $ e $ 3 $ *no caso escalar*.
#
# Continuando a derivar poderíamos encontrar $ T_j $ para $ j $ qualquer, mas não o faremos pelo motivo já indicado no caso geral: as expressões resultantes são complicadas demais para serem valiosas.

# %% [markdown]
# ## $ \S 5 $ Implementação do método de Taylor de ordem $ 2 $ no caso escalar
#
# *Para aplicar o método de Taylor de ordem $ m $, precisamos conhecer todas as derivadas parciais de ordem até $ m - 1 $ da função $ f $ (ou $ \boldsymbol F $) que define a equação diferencial*. Temos duas opções na implementação:
# * Podemos calcular estas derivadas analiticamente e passá-las como entradas;
# * Podemos fornecer apenas a função $ f $ como entrada, e deixar a determinação das derivadas para o computador, usando algum método de diferenciação numérica.
#
# A segunda opção é muito mais conveniente e geral, já que não precisamos calcular nós mesmos estas derivadas para cada EDO à qual o método será aplicado. Porém, ela tem a desvantagem que, quando as derivadas não são determinadas simbolicamente, estamos introduzindo erros já na *fórmula* que define as aproximações. Para piorar, os métodos mais comuns de diferenciação numérica tem precisão relativamente baixa.
#
# Por este motivo, na implementação abaixo do método de Taylor de ordem $ 2 $ no caso escalar, é o usuário quem deve calcular e fornecer as derivadas parciais $ f_t $ e $ f_y $.

# %%
def taylor_2(f, f_t, f_y, t_0, y_0, T, h):
    """
    Fornece uma solução numérica de um PVI de 1a ordem da forma:
        y' = f(t, y), y(t_0) = y_0
    usando o método de Taylor de ordem 2.
    Entradas:
        * A função escalar f = f(t, y) que define a EDO.
        * A derivada f_t de f com respeito a t.
        * A derivada f_y de f com respeito a y.
        * O instante inicial t_0.
        * O escalar y_0 tal que y(t_0) = y_0 é a condição inicial.
        * O instante (nodo) T final.
        * O tamanho do passo h, que deve ter o mesmo sinal que T - t_0.
    Saídas:
        * Um array ts = [t_0, t_1, ..., t_N = T] onde t_i = t_0 + ih
          para i = 0, 1, ..., N - 1 e T - t_{N - 1} <= h.
        * Um array correspondente ys = [y_0, y_1, ..., y_N] contendo
          as aproximações para a solução analítica em t_i.
    """
    import numpy as np
    
    def T_1(t, y):
        return f(t, y)
    
    def T_2(t, y):
        return f_t(t, y) + f_y(t, y) * f(t, y)
        
    sinal = np.sign(h)
    assert np.sign(T - t_0) == sinal
    ts = [t_0]
    ys = [y_0]
    t = t_0
    y = y_0
    
    # Enquanto não atingimos T, atualizamos Y = Y_i usando a fórmula
    # do método. Depois incrementamos (ou decrementamos) t por h.
    while sinal * (T - t) > 0:    # t < T (se h > 0) ou T < t (se h < 0)
        # Se falta menos que |h| para chegar em T, usamos um passo menor:
        h = sinal * min(abs(h), abs(T - t))
        y += h * (T_1(t, y) + h * T_2(t, y) / 2)
        t += h
        ys.append(y)
        ts.append(t)
    
    return np.array(ts), np.array(ys)

# %% [markdown]
# ## $ \S 6 $ Estimativa para o erro no método de Taylor de ordem $ m $
#
# Pelo teorema de Taylor com resto, o **erro local**, i.e., o erro envolvido no *primeiro* passo, é da ordem de $ \abs{h}^{m+1} $:
# $$
# \boxed{\boldsymbol E_1 = \boldsymbol y(t_1) - \boldsymbol y_1 \in O(h^{m+1})}
# $$
# Assim como para o método de Euler, uma estimativa do **erro global**, ou seja, da diferença
# $ \boldsymbol E_N = \boldsymbol y(t_N) - \boldsymbol y_N $
# entre o valor exato e o valor aproximado no *último* nodo $ t_N $, pode ser obtida assumindo-se que o erro a cada passo é constante. Após $ N $ passos, é de se esperar que o erro global seja da ordem de $ \abs{h}^m $:
# $$
# \boldsymbol E_N \approx N\, \boldsymbol E_1 = \frac{t_N - t_0}{h}\,\boldsymbol E_1.
# $$
# Em símbolos:
# $$
# \boxed{\boldsymbol E_N = \boldsymbol y(t_N) - \boldsymbol y_N \in O(h^m)}
# $$
#
# 📝 Segue imediatamente que para $ \abs{h} $ pequeno, quanto maior o valor de $ m $, mais precisa será a solução numérica fornecida pelo método de Taylor. Porém esta maior precisão vem ao custo da determinação (analítica ou numérica) da expressão dos $ \boldsymbol T_j $ que aparecem na fórmula geral para cada $ j $ de $ 1 $ até $ m $. A dificuldade desta determinação cresce rapidamente conforme $ m $ aumenta. Por isto na prática outros métodos para resolução de problemas de valor inicial são preferidos.

# %% [markdown]
# ## $ \S 7 $ Problemas
#
# 📝 A $ \S 8 $ contém os procedimentos para impressão e plotagem de soluções numéricas criados no caderno anterior. Recomenda-se aproveitá-los na resolução dos problemas abaixo.
#
# **Exemplo 1:** Considere o problema de valor inicial de primeira ordem
# $$
# ty' + y = t\cos(4t)\,, \quad y(1) = 3.
# $$
#
# (a) Use o método de Taylor de ordem $ 2 $ para estimar $ y(8) $ com passos $ h $ de tamanhos $ 1 $, $ 0.5 $, $ 0.1 $,  $ 0.05 $ e $ 0.01 $.
#
# (b) Compare graficamente cada uma das soluções numéricas obtidas com a solução "exata" usando o procedimento `compara_solucao` da $ \S 8 $.

# %%
import numpy as np


# Item (a):
# Isolando y' do lado esquerdo, o lado direito é f(t, y):
f = lambda t, y: y / t + np.cos(4 * t)
# Precisamos também das derivadas parciais:
f_t = lambda t, y: -y / t**2 - 4 * np.sin(t)
f_y = lambda t, y: -1 / t
t_0 = 1
y_0 = 3
T = 8
hs = [1, 0.5, 0.1, 0.05, 0.01]
for h in hs:
    ts, ys = taylor_2(f, f_t, f_y, t_0, y_0, T, h)
    imprime_solucao(ts, ys, 0)


# Item (b):
for h in hs:
    ts, ys = taylor_2(f, f_t, f_y, t_0, y_0, T, h)
    compara_solucao(f, t_0, y_0, ts, ys)
# Out:
#        t              y_0
# ------------------------------
#       1.00000        3.00000
#       8.00000        2.03538
# ------------------------------
#
#        t              y_0
# ------------------------------
#       1.00000        3.00000
#       8.00000       11.50164
# ------------------------------
#
#        t              y_0
# ------------------------------
#       1.00000        3.00000
#       8.00000       21.89076
# ------------------------------
#
#        t              y_0
# ------------------------------
#       1.00000        3.00000
#       8.00000       23.52204
# ------------------------------
#
#        t              y_0
# ------------------------------
#       1.00000        3.00000
#       8.00000       24.90250
# ------------------------------

# %% [markdown]
# **Problema 1:** Encontre com a maior precisão possível o valor aproximado em $ t = 3 $ para a solução do problema de valor inicial:
# $$
# \begin{cases}
# ty' = t - y \\
# y(1) = 2
# \end{cases}
# $$

# %% [markdown]
# *Solução:*

# %% [markdown]
# **Problema 2:**
#
# (a) Usando o método de Taylor de ordem 2 com $ h = -0.1 $, $ h = -0.05 $ e $ h = -0.01 $, integre o problema de valor inicial
# $$
# \begin{cases}
#     y' = y \sin x + \cos x \\
#     y(\pi) = 0
# \end{cases}
# $$
# para estimar $ y(-5) $.
#
# (b) Compare graficamente as soluções obtidas no item (a) com a solução analítica, usando o procedimento `compara_solucao`.

# %% [markdown]
# *Solução:*

# %% [markdown]
# **Problema 3:** Considere o problema de valor inicial
# $$
# y' = x^2 + y, \quad y(0) = 3.
# $$
#
# (a) Use o método de Taylor de segunda ordem para resolvê-lo numericamente no intervalo $ [0,3] $ com passos $ h $ de tamanhos $ 1 $, $ 0.5 $, $ 0.1 $ e  $ 0.05 $.
#
# (b) Compare graficamente as soluções obtidas com a solução analítica.
#
# (c) Faça o mesmo para o PVI
# $$
# y' = y^2, \quad y(0) = 3.
# $$
# Você consegue explicar o resultado inesperado? *Dica:* Encontre a solução analítica (sem usar o computador) e note que ela possui uma singularidade dentro do intervalo $ [0, 3] $.

# %% [markdown]
# *Solução:*

# %% [markdown]
# **Problema 4:** Implemente o método de Taylor de ordem $ 3 $ para problemas de valor inicial escalares (de ordem $ 1 $).

# %% [markdown]
# *Solução:*

# %% [markdown]
# **Problema 5:**
#
# (a) Use os métodos de Taylor de ordem $ 1 $ (método de Euler do caderno anterior), $ 2 $ e $ 3 $ com $ h = 0.05 $ para resolver o problema de valor inicial
# $$
# \begin{cases}
#     y' = y  \\
#     y(-2) = 3
# \end{cases}
# $$
# no intervalo $ [-2, 10] $.
#
# (b) Compare os resultados graficamente. Plote também a solução analítica, dada por:
# $$
# y(t) = 3e^{t+2}.
# $$

# %% [markdown]
# *Solução:*

# %% [markdown]
# ## $ \S 8 $ Procedimentos para impressão e plotagem da solução numérica

# %%
def imprime_solucao(ts, Ys, freq):
    """
    Dados dois arrays ts e Ys de mesmo comprimento, imprime um
    a cada 'freq' de seus valores por linha, na forma de uma
    tabela. Os 0-ésimos e últimos valores sempre são impressos.
    """
    def imprime_cabecalho(r):
        """
        Imprime o cabeçalho da tabela.
        """
        print("\n       t              ", end="")
        for j in range(r):
            print(f"y_{j}            ", end="")
        print()
        for j in range(r + 1):
            print("---------------", end="")
        print()
        
        
    def imprime_linha(t, Y, r):
        """
        Imprime uma das linhas da tabela.
        """
        print("{:13.5f}".format(t), end="")
        # Para dimensão r > 1:
        if r > 1:
            for j in range(r):
                print("  {:13.5f}".format(Y[j]), end="")
            print()
        # Para dimensão r = 1:
        else:
            print("  {:13.5f}".format(Y))
    
    N = len(Ys) - 1        # N + 1 é o número de nodos; N o de passos.
    try:
        r = len(Ys[0])     # Dimensão de cada entrada Y de Ys.
    except TypeError:
        r = 1
    if freq == 0:          # Se freq == 0, imprime apenas os últimos valores.
        freq = N
    imprime_cabecalho(r)
    for i in range(0, N + 1, freq):
        imprime_linha(ts[i], Ys[i], r)
    if i != N:
        imprime_linha(ts[N], Ys[N], r)
    for j in range(r + 1):
            print("---------------", end="")
    print()
        
    return None

# %%
def compara_solucao(f, t_0, y_0, ts, ys):
    """ Representa graficamente as seguintes soluções do PVI (escalar)
            y' = f(t, y), y(t_0) = y_0
    (1) Uma solução numérica dada pelos dois arrays (ou listas)
        ts e ys, calculada previamente por um método qualquer.
    (2) A solução obtida pela rotina `odeint` da biblioteca SciPy.
    Entradas:
        * A função escalar f(t, y) que define a EDO.
        * O instante inicial t_0.
        * O escalar y_0 tal que y(t_0) = y_0 é a condição inicial.
        * A lista ts dos nodos t_i.
        * A lista ys das aproximações y_i obtidas.
    """
    import matplotlib.pyplot as plt
    import numpy as np
    from scipy.integrate import odeint
    
    
    ts_exata = np.linspace(t_0, T, num=201)
    ys_exata = odeint(f, y_0, ts_exata, tfirst=True)
    
    plt.plot(ts, ys, 'o')
    plt.plot(ts_exata, ys_exata, '-')
    plt.grid(True)
    plt.xlabel('t')
    plt.ylabel('y')
    plt.legend(("Numérica", "Exata"), loc=0)
    plt.show()
    
    return None
