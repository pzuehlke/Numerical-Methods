# %% [markdown]
# $ \newcommand{\mbf}{\mathbf} $
# $ \newcommand{\norm}[1]{\left\Vert#1\right\Vert} $
# $ \newcommand{\abs}[1]{\left\vert#1\right\vert} $
# $ \newcommand{\Rar}{\Longrightarrow} $
# $ \newcommand{\Dar}{\Longleftrightarrow} $
#
# # Métodos de Taylor
#
# ## $ \S 1 $ Recordação do método de Euler
#
# Pelo menos para $ h $ pequeno, uma função
# $$
# \mbf y (t) = \big(y_0(t),\, y_1(t), \cdots,\, y_{r-1}(t)\big)
# $$
# é bem aproximada pelo seu polinômio de Taylor de ordem 1:
# \begin{equation*}
# \mbf y(t+h) \approx \mbf y(t) + h\,\mbf y'(t).
# \end{equation*}
#
# Portanto, se $ \mbf y $ é a solução de um problema de valor inicial de primeira ordem em $ \mathbb R^r $:
# \begin{equation*}\label{E:ivp}
# \begin{cases}
# \mbf y' = \mbf F(t, \mbf y) \\
# \mbf y(t_0) = \mbf y_0
# \end{cases}
# \quad \text{onde} \quad \mbf y = \big(y_0, y_1, \dots, y_{r-1}\big)\,, \tag{1}
# \end{equation*}
# então
# \begin{equation*}
# \mbf y(t+h) \approx \mbf y(t) + h\,\mbf F\big(t, \mbf y(t)\big).
# \end{equation*}
#
# Esta relação é a base do *método de Euler* do caderno anterior. Partindo de $ \mbf y(t_0) = \mbf y_0 $ e procedendo em incrementos de tamanho $ h $, conseguimos uma estimativa $ \mbf y_i $ para o valor de $ \mbf y $ no nodo $ t_{i} $ a partir da estimativa $ \mbf y_{i - 1} $ no nodo anterior:
# \begin{equation*}
# \mbf y_{i} = \mbf y_{i-1} + h\,\mbf F(t_{i-1}, \mbf y_{i-1}) \quad \text{onde $t_i = t_0 + ih$} \quad (i = 1, \dots, N).
# \end{equation*}
#
# ## $ \S 2 $ Idéia do método de Taylor de ordem $ m $
#
# Usando o polinômio de Taylor de ordem $ m \ge 1 $, obtemos uma aproximação ainda mais precisa para $ \mbf y(t+h) $ a partir da informação sobre $ \mbf y $ e suas derivadas em $ t $:
# \begin{equation*}\label{E:Taylor}
# \mbf y(t+h) \approx \mbf y(t) + h\,\mbf y'(t) + \frac{h^2}{2}\,\mbf y'(t) + \cdots + \frac{h^m}{m!}\mbf y^{(m)}(t)\,. \tag{3}
# \end{equation*}
# Pela fórmula para o resto no teorema de Taylor, o erro envolvido é aproximadamente proporcional a $ h^{m+1} $.
#
# Se $ \mbf y $ é a solução analítica do problema de valor inicial \eqref{E:ivp}, então
# \begin{equation*}\label{E:derivative}
# \mbf y'(t) = \mbf F\big(t, \mbf y(t)\big). \tag{4}
# \end{equation*}
# Derivando com respeito a $ t $ usando a regra da cadeia, obtemos uma fórmula para $ \mbf y'' $:
# $$
# \mbf y''(t) = \mbf T_2\big(t,\mbf y(t)\big)\,.
# $$
# Os detalhes podem ser encontrados na $ \S 5 $, mas o que importa aqui é que esta expressão envolve apenas $ \mbf F $, suas derivadas parciais de primeira ordem, $ t $ e $ \mbf y(t) $, mas não $ \mbf y'(t) $, já que por \eqref{E:derivative} esta última pode ser expressa como $ \mbf F\big(t,y(t)\big) $.
#
# Da mesma maneira, derivando sucessivamente \eqref{E:derivative} com respeito a $ t $, obtemos uma expressão para $ \mbf y^{(j)} $ da forma:
# \begin{equation*}\label{E:T}
# \mbf y^{(j)}(t) = \mbf T_j\big(t,\mbf y(t)\big) \qquad (j = 1, 2, \dots)\,. \tag{5}
# \end{equation*}
# A expressão à direita é complicada, pois envolve todas as derivadas parciais de $ \mbf F $ de ordem $ \le j - 1 $. Contudo, por indução, podemos escrevê-la de modo que *ela não dependa de*
# $$
# \mbf y'(t),\ \mbf y''(t), \cdots,\ \mbf y^{(j-1)}(t),
# $$
# apenas de $ \mbf y(t) $, como já indicado pela notação.
#
# Sejam $ N \ge 1 $ um inteiro, $ h > 0 $ o **tamanho do passo** e
# $$
# t_i = t_0 + ih \qquad (i = 0, 1, \dots, N)
# $$
# os **nodos** correspondentes. No **método de Taylor de ordem $ m $**, definimos a aproximação $ \mbf y_i $ para o valor preciso $ \mbf y(t_i) $ da solução de \eqref{E:ivp} usando a aproximação polinomial de ordem $ m $ em \eqref{E:Taylor}, mas substituindo $ \mbf y^{(j)} $ pelo lado direito em \eqref{E:T} para cada $ j $:
# \begin{equation*}\label{E:method}
# \boxed{\mbf y_{i} = \mbf y_{i-1} + h\,\mbf T_1\big(t_{i-1},\mbf y_{i-1}\big) +
# \frac{h^2}{2}\,\mbf T_2\big(t_{i-1},\mbf y_{i-1}\big) + \cdots + \frac{h^m}{m!}\mbf T_m\big(t_{i-1},\mbf y_{i-1}\big)} \tag{6}
# \end{equation*}
# onde $t_i = t_0 + ih$ para cada $ i = 1, \dots, N $.
#
# 📝 Tomando $ m = 1 $, recuperamos o método de Euler.
#
# 📝 A fórmula acima não é muito útil porque os $ \mbf T_j $ não foram determinados. Faremos isto nas seções seguintes em casos especiais.

# %% [markdown]
# ## $ \S 3 $ Fórmulas do método de Taylor de ordem $ m = 2 $  e $ m = 3 $ para um problema de valor inicial escalar
#
# Para simplificar, considere inicialmente um PVI de primeira ordem *escalar* (ou seja, com $ r = 1 $):
# \begin{equation*}
# \begin{cases}
# y' = f(t, y) \\
# y(t_0) = y_0
# \end{cases}
# \end{equation*}
# Derivando a relação
# $$
# y'(t) = f(t, y(t)) =: T_1\big(t,y(t)\big)
# $$
# com respeito a $ t $ usando a regra da cadeia, deduzimos que:
# \begin{alignat*}{9}
# y''(t) &= f_t\big(t, y(t)\big) + f_y\big(t, y(t)\big)\,y'(t) \\
# & = f_t\big(t, y(t)\big) + f_y\big(t, y(t)\big)\,f\big(t, y(t)\big).
# \end{alignat*}
# Ou, omitindo os parâmetros:
# \begin{equation*}
# y'' = f_t + f_y\,f
# \end{equation*}
# Na notação da seção anterior:
# \begin{equation*}\label{E:T1}
# \boxed{T_2 = f_t + f_y\,f.}
# \end{equation*}
# Derivando mais uma vez com ajuda da regra da cadeia, obtemos:
# \begin{alignat*}{9}
# y''' = y^{(3)} &= f_{tt} + 2f_{ty}\,f + f_{yy}\,f^2 + \\
# &+ f_t\,f_y +  f_y^2\,f.
# \end{alignat*}
# Assim:
# \begin{equation*}\label{E:T2}
# \boxed{T_3 = f_{tt} + 2f_{ty}\,f + f_{yy}\,f^2 +
# + f_t\,f_y +  f_y^2\,f.}
# \end{equation*}
#
# Continuando, poderíamos encontrar $ T_j $ para $ j $ qualquer, mas não o faremos.
#
# 📝 Observe que estas fórmulas são válidas apenas se $ y $ é uma função escalar ($ r = 1 $).

# %% [markdown]
# ## $ \S 3 $ Implementação do método de Taylor de ordem $ 2 $ (caso escalar)

# %%
def taylor_2(f, f_t, f_y, t_0, Y_0, T, h):
    """
    Fornece uma solução numérica de um problema de valor inicial de
    1a ordem da forma y' = f(t, y), y(t_0) = y_0 usando o método de Taylor
    de ordem 2.
    Entradas:
        * A função escalar f(t, y) que define a EDO.
        * A derivada f_t de f com respeito a t.
        * A derivada f_y de f com respeito a y.
        * O instante inicial t_0.
        * Um vetor ou escalar y_0 tal que y(t_0) = y_0 é a condição inicial.
        * O instante T final.
        * O tamanho do passo h.
    Saídas:
        * Um array ts = [t_0, t_1, ..., t_N = T] onde t_i = t_0 + ih
          para i = 0, 1, ..., N - 1 e T - t_{N - 1} <= h.
        * Um array correspondente ys = [y_0, y_1, ..., y_N] contendo
          as aproximações para a solução analítica em t_i.
    """
    import numpy as np
    
    def T_1(t, y):
        return f(t, y)
    
    def T_2(t, y):
        return f_t(t, y) + f_y(t, y) * f(t, y)
    
    ts = [t_0]
    ys = [y_0]
    t = t_0
    y = y_0
    while t < T:
        h = min(h, T - t)
        y += h * (T_1(t, y) + h * T_2(t, y) / 2)
        t += h
        ys.append(y)
        ts.append(t)
    
    return np.array(ts), np.array(ys)

# %% [markdown]
# ## $ \S 4 $ Fórmula do método de Taylor de ordem $ m = 2 $ para um problema de valor inicial vetorial
#
# Suponha novamente que $ \mbf y $ seja a solução analítica da equação diferencial vetorial
# $$
# \mbf y' = \mbf F(t, \mbf y)=: \mbf T_1(t, y).
# $$
# Derivando esta igualdade com respeito a $ t $ usando a regra da cadeia, obtemos uma fórmula para $ \mbf y'' $ que envolve $ \mbf F $, suas derivadas parciais de primeira ordem, e $ \mbf y $, mas não $ \mbf y' $:
# \begin{alignat*}{9}
# \mbf y'' &= \mbf F_t + \sum_{k=0}^{r-1}\mbf F_{y_k} y_k' \\
# &= \mbf F_t + \sum_{k=0}^{r-1}\mbf F_{y_k} f_k \qquad \text{onde }\mbf F = (f_0,f_1,\dots,f_{r-1}).
# \end{alignat*}
# Aqui $ \mbf F_t $ denota a derivada parcial de $ \mbf F $ com respeito a $ t $ e $ \mbf F_{y_k} $ aquela com respeito à $ k $-ésima coordenada de $ \mbf y $.
# Na notação da $ \S 2 $, concluímos portanto que
# $$
# \boxed{\mbf T_2 = \mbf F_t + \sum_{k=0}^{r-1}\mbf F_{k_j} f_k} \qquad \big(\mbf F = (f_0,f_1,\dots,f_{r-1})\big)\,.
# $$
# Substituindo as expressões para $ \mbf T_1 $ e $ \mbf T_ 2$ na eq. (6) da $ \S 2 $, obtemos a fórmula para o método de Taylor de ordem $ 2 $ no caso vetorial.
#
# 📝 Derivando sucessivamente a expressão para $ \mbf y'' $ poderíamos deduzir as fórmulas para qualquer $ \mbf T_j $, mas, novamente, não o faremos aqui.

# %% [markdown]
# ## $ \S 5 $ Estimativa para o erro no método de Taylor de ordem $ m $
#
# Pelo teorema de Taylor com resto, o **erro local**, i.e., o erro envolvido no primeiro passo, é da ordem de $ h^{m+1} $:
# $$
# \boxed{\mbf E_1 = \mbf y(t_1) - \mbf y_1 \in O(h^{m+1})}
# $$
# Assim como para o método de Euler, uma estimativa do **erro global**, ou seja, da diferença
# $ \mbf E_N = \mbf y(t_N) - \mbf y_N $
# entre o valor exato e o valor aproximado no último nodo $ t_N $, pode ser obtida assumindo-se que o erro a cada passo é constante. Após $ N $ passos, é de se esperar que o erro global seja da ordem de $ h^m $:
# $$
# \mbf E_N \approx N \mbf E_1 = \frac{t_N - t_0}{h}\,\mbf E_1.
# $$
# Em símbolos:
# $$
# \boxed{\mbf E_N = \mbf y(t_N) - \mbf y_N \in O(h^m)}
# $$
#
# 📝 Segue imediatamente que quanto maior o valor de $ m $, mais precisa será a solução numérica fornecida pelo método de Taylor. Porém esta maior precisão vem ao custo da determinação da expressão explícita para os $ \mbf T_j $ para cada $ j $ de $ 1 $ até $ m $, que aparecem na fórmula. A dificuldade desta determinação cresce rapidamente conforme $ m $ aumenta, pois requer o cálculo de todas as derivadas parciais de $ \mbf F $ de ordem até $ m - 1 $.

# %% [markdown]
# ## $ \S 6 $ Problemas
#
# 📝 A $ \S 7 $ contém os dois procedimentos para impressão e plotagem de soluções numéricas criados no caderno anterior.

# %% [markdown]
# **Problema 1:** Encontre o valor aproximado em $ t = 3 $ para a solução do problema de valor inicial:
# $$
# \begin{cases}
# ty' = t - y \\
# y(2) = 2
# \end{cases}
# $$

# %%
import numpy as np

t_0 = 2
y_0 = 2
h = 0.05
T = 3

def f(t, y):
    return 1 - y / t

def f_t(t, y):
    return 1 + y / (t**2)

def f_y(t, y):
    return 1 - 1 / t

ts, ys = taylor_2(f, f_t, f_y, t_0, y_0, T, h)
imprime_solucao(ts, ys, 5)
# Out:
#         t            y_0
# ------------------------------
#        2.0000       2.0000
#        2.2500       2.0202
#        2.5000       2.0625
#        2.7500       2.1209
#        3.0000       2.1913
#        3.0000       2.1913

# %%
plota_poligonal(ts, ys)

# %% [markdown]
# **Problema 2:** Usando o método de Taylor de ordem 2 com $ h = 0.1 $, $ h = 0.05 $ e $ h = 0.01 $, integre o problema de valor inicial
# $$
# \begin{cases}
#     y' = y \sin x + \cos x \\
#     y(0) = 0
# \end{cases}
# $$
# para estimar $ y(0.5) $.

# %% [markdown]
# **Problema 3:** Considere o problema de valor inicial de primeira ordem
# $$
# y' = t^2 + y, \quad y(0) = 3.
# $$
#
# (a) Use o método de Taylor de segunda ordem para resolvê-lo numericamente no intervalo $ [0,3] $ com passos $ h $ de tamanhos $ 1 $, $ 0.5 $, $ 0.1 $ e  $ 0.05 $.
#
# (b) Compare graficamente as soluções obtidas com a solução analítica.
#
# (c) Faça o mesmo para o PVI
# $$
# y' = y^2, \quad y(0) = 3.
# $$
# Você consegue explicar o resultado inesperado?

# %% [markdown]
# **Problema 4:** Implemente o método de Taylor de ordem $ 3 $ para problemas de valor inicial escalares de ordem $ 1 $.

# %% [markdown]
# **Problema 5:**
#
# (a) Use os métodos de Taylor de ordem $ 1 $ (método de Euler), $ 2 $ e $ 3 $ com $ h = 0.05 $ para resolver o problema de valor inicial
# $$
# \begin{cases}
#     y' = y  \\
#     y(1) = 1
# \end{cases}
# $$
# no intervalo $ [1, 4] $.
#
# (b) Compare os resultados graficamente. Plote também a solução analítica, dada por:
# $$
# y(t) = e^{t-1}.
# $$

# %% [markdown]
# ## $ \S 7 $ Procedimentos para impressão e plotagem da solução numérica

# %%
def imprime_solucao(ts, Ys, freq):
    """
    Dados dois arrays ts e Ys de mesmo comprimento, imprime um
    a cada 'freq' de seus valores por linha, na forma de uma
    tabela. Os 0-ésimos e últimos valores sempre são impressos.
    """
    def imprime_cabecalho(r):
        """
        Imprime o cabeçalho da tabela.
        """
        print("\n        t            ", end="")
        for j in range(r):
            print(f"y_{j}          ", end="")
        print()
        for j in range(r + 1):
            print("---------------", end="")
        print()
        
        
    def imprime_linha(t, Y, r):
        """
        Imprime uma das linhas da tabela.
        """
        print("{:13.4f}".format(t), end="")
        # Para dimensão r > 1:
        if r > 1:
            for j in range(r):
                print("{:13.4f}".format(Y[j]), end="")
            print()
        # Para dimensão r = 1:
        else:
            print("{:13.4f}".format(Y))
    
    
    N = len(Ys) - 1        # N + 1 é o número de nodos; N o de passos.
    try:
        r = len(Ys[0])     # Dimensão de cada entrada Y de Ys.
    except TypeError:
        r = 1
    if freq == 0:          # Se freq == 0, imprime apenas os últimos valores.
        freq = N
    imprime_cabecalho(r)
    for i in range(0, N + 1, freq):
        imprime_linha(ts[i], Ys[i], r)
    if i != N:
        imprime_linha(ts[N], Ys[N], r)
        
    return None

# %%
def plota_poligonal(ts, ys):
    """
    Dados arrays ou listas numéricos ts e ys de mesmo comprimento,
    plota a curva poligonal de vértices (ts[i], ys[i]).
    """
    import matplotlib.pyplot as plt
    
    plt.plot(ts, ys, '-')
    plt.grid(True)
    plt.xlabel('t')
    plt.ylabel('y')
    plt.show()
    
    return None
